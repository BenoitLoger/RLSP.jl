# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from scipy.stats import pearsonr
from statsmodels.iolib.table import SimpleTable
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_19903/1506026403.py in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# ----> 4 from statsmodels.tsa.arima.model import ARMA
#       5 from scipy.stats import pearsonr
#       6 from statsmodels.iolib.table import SimpleTable
#
# ImportError: cannot import name 'ARMA' from 'statsmodels.tsa.arima.model' (/usr/local/lib/python3.10/dist-packages/statsmodels/tsa/arima/model.py)

# %%
df = pd.read_csv('../Instances/1/demands.csv')
plt.figure(figsize=(12,6))
ice_cream, = plt.plot(df['d'])
plt.legend(['Demand'], fontsize=16)

# %%
plot_pacf(df['d'])
plt.show()

# %%
model = ARIMA(df,order=(1,0,0))

# %%
model_fit = model.fit()

# %%
beta = model_fit.arparams
theta = model_fit.maparams
p_values = model_fit.pvalues
print(beta)
print(theta)
# Out:
# const     0.000000e+00
# ar.L1     7.946086e-09
# sigma2    8.756188e-13
# dtype: float64

# %%
residuals = pd.DataFrame(model_fit.resid, columns=['residuals'])
residuals.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>
